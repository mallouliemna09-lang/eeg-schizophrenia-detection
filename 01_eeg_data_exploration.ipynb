# %% [markdown]
# # EEG Data Exploration
#
# This notebook explores the structure of the EEG recordings used in this project.
# The objective is to load the EEG file, inspect its metadata, and visualize the raw brain signals before applying preprocessing and machine learning techniques.

# %% [markdown]
# ## Objectives
#
# The goal of this notebook is to:
#
# - Load EEG data from an EDF file
# - Inspect the recording metadata
# - Visualize multi-channel EEG signals
# - Plot the signal of a specific channel
#
# This step helps understand the structure and characteristics of the EEG recordings before applying signal processing methods such as EMD or LMS.

# %%
import mne
import matplotlib.pyplot as plt

file_path = "h01.edf"
raw = mne.io.read_raw_edf(file_path, preload=True)

# Afficher les informations générales sur le fichier
print(raw.info)

# Visualiser les données brutes
raw.plot(title="Visualisation du signal EEG")


plt.show()
# Out:
# Extracting EDF parameters from /content/h01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 231249  =      0.000 ...   924.996 secs...
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp2, F8, T4, T6, O2, Fp1, F7, T3, T5, O1, F4, C4, P4, F3, C3, ...
#  chs: 19 EEG
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 125.0 Hz
#  meas_date: 2003-06-23 16:14:37 UTC
#  nchan: 19
#  projs: []
#  sfreq: 250.0 Hz
#  subject_info: 1 item (dict)
# >
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %% [markdown]
# ## EEG Recording Overview
#
# The EEG data is stored in EDF (European Data Format), a common format used for physiological signals.
#
# The recording contains:
# - multiple EEG channels
# - a sampling frequency of 250 Hz
# - approximately 19 electrodes placed according to the standard EEG montage
#
# Each channel represents electrical brain activity measured over time.

# %%
channel_name = "Fz"
data, times = raw[channel_name, :]
plt.plot(times, data[0])
plt.title(f"Signal EEG - {channel_name}")
plt.xlabel("Temps (s)")
plt.ylabel("Amplitude (µV)")
plt.show()
